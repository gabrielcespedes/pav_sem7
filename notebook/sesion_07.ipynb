# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_clean = pd.read_csv('/content/sales_clean.csv')

# %%
df_clean.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
from exploracion import calidad_datos, graficos

# %%
calidad_datos(df_clean)
# Out:
#                   tipo  nan  porcentaje_nan  ceros  porcentaje_ceros   count  \
# Row ID           int64    0        0.000000      0               0.0  9800.0
# Quantity         int64    0        0.000000      0               0.0  9800.0
# Sales          float64    0        0.000000      0               0.0  9800.0
# Postal Code    float64   11        0.112245      0               0.0  9789.0
# Total Sales    float64    0        0.000000      0               0.0  9800.0
# Product Name    object    0        0.000000      0               0.0    9800
# Sub-Category    object    0        0.000000      0               0.0    9800
# Category        object    0        0.000000      0               0.0    9800
# Product ID      object    0        0.000000      0               0.0    9800
# Region          object    0        0.000000      0               0.0    9800
# State           object    0        0.000000      0               0.0    9800
# ...

# %%
no_cols = ["Row ID", "Order ID", "Customer ID", "Product ID", "Product Name"]

# %%
cols_graph = []

for c in df_clean.columns:
  if c not in no_cols:
    cols_graph.append(c)

# %%
cols_graph
# Out:
# ['Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal Code',
#  'Region',
#  'Category',
#  'Sub-Category',
#  'Sales',
#  'Quantity',
#  'Total Sales',
#  'Level Sales']

# %%
graficos(calidad_datos(df_clean), df_clean, cols_graph)
